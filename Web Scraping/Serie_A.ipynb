# %%
import requests

# %%
standings_url = 'https://fbref.com/en/comps/11/2021-2022/2021-2022-Serie-A-Stats'

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/dc56fe14/2021-2022/Milan-Stats',
#  '/en/squads/d609edc0/2021-2022/Internazionale-Stats',
#  '/en/squads/d48ad4ff/2021-2022/Napoli-Stats',
#  '/en/squads/e0652b02/2021-2022/Juventus-Stats',
#  '/en/squads/7213da33/2021-2022/Lazio-Stats',
#  '/en/squads/cf74a709/2021-2022/Roma-Stats',
#  '/en/squads/421387cf/2021-2022/Fiorentina-Stats',
#  '/en/squads/922493f3/2021-2022/Atalanta-Stats',
#  '/en/squads/0e72edf2/2021-2022/Hellas-Verona-Stats',
#  '/en/squads/105360fe/2021-2022/Torino-Stats',
#  '/en/squads/e2befd26/2021-2022/Sassuolo-Stats',
#  '/en/squads/04eea015/2021-2022/Udinese-Stats',
#  '/en/squads/1d8099f8/2021-2022/Bologna-Stats',
#  '/en/squads/a3d88bd8/2021-2022/Empoli-Stats',
#  '/en/squads/8ff9e3b3/2021-2022/Sampdoria-Stats',
#  '/en/squads/68449f6d/2021-2022/Spezia-Stats',
#  '/en/squads/c5577084/2021-2022/Salernitana-Stats',
#  '/en/squads/c4260e09/2021-2022/Cagliari-Stats',
#  '/en/squads/658bf2de/2021-2022/Genoa-Stats',
# ...

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/dc56fe14/2021-2022/Milan-Stats',
#  'https://fbref.com/en/squads/d609edc0/2021-2022/Internazionale-Stats',
#  'https://fbref.com/en/squads/d48ad4ff/2021-2022/Napoli-Stats',
#  'https://fbref.com/en/squads/e0652b02/2021-2022/Juventus-Stats',
#  'https://fbref.com/en/squads/7213da33/2021-2022/Lazio-Stats',
#  'https://fbref.com/en/squads/cf74a709/2021-2022/Roma-Stats',
#  'https://fbref.com/en/squads/421387cf/2021-2022/Fiorentina-Stats',
#  'https://fbref.com/en/squads/922493f3/2021-2022/Atalanta-Stats',
#  'https://fbref.com/en/squads/0e72edf2/2021-2022/Hellas-Verona-Stats',
#  'https://fbref.com/en/squads/105360fe/2021-2022/Torino-Stats',
#  'https://fbref.com/en/squads/e2befd26/2021-2022/Sassuolo-Stats',
#  'https://fbref.com/en/squads/04eea015/2021-2022/Udinese-Stats',
#  'https://fbref.com/en/squads/1d8099f8/2021-2022/Bologna-Stats',
#  'https://fbref.com/en/squads/a3d88bd8/2021-2022/Empoli-Stats',
# ...

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
matches
# Out:
#           Date   Time          Comp           Round  Day Venue Result  GF  GA  \
# 0   2021-08-23  20:45       Serie A     Matchweek 1  Mon  Away      W   1   0
# 1   2021-08-29  20:45       Serie A     Matchweek 2  Sun  Home      W   4   1
# 2   2021-09-12  18:00       Serie A     Matchweek 3  Sun  Home      W   2   0
# 3   2021-09-15  20:00  Champions Lg     Group stage  Wed  Away      L   2   3
# 4   2021-09-19  20:45       Serie A     Matchweek 4  Sun  Away      D   1   1
# 5   2021-09-22  20:45       Serie A     Matchweek 5  Wed  Home      W   2   0
# 6   2021-09-25  15:00       Serie A     Matchweek 6  Sat  Away      W   2   1
# 7   2021-09-28  21:00  Champions Lg     Group stage  Tue  Home      L   1   2
# 8   2021-10-03  20:45       Serie A     Matchweek 7  Sun  Away      W   3   2
# 9   2021-10-16  20:45       Serie A     Matchweek 8  Sat  Home      W   3   2
# 10  2021-10-19  20:00  Champions Lg     Group stage  Tue  Away      L   0   1
# ...

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/dc56fe14/2021-2022/matchlogs/all_comps/shooting/Milan-Match-Logs-All-Competitions',
#  '/en/squads/dc56fe14/2021-2022/matchlogs/all_comps/shooting/Milan-Match-Logs-All-Competitions',
#  '/en/squads/dc56fe14/2021-2022/matchlogs/all_comps/shooting/Milan-Match-Logs-All-Competitions',
#  '/en/squads/dc56fe14/2021-2022/matchlogs/all_comps/shooting/Milan-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting
# Out:
#      For Milan                                                               \
#           Date   Time          Comp           Round  Day Venue   Result  GF
# 0   2021-08-23  20:45       Serie A     Matchweek 1  Mon  Away        W   1
# 1   2021-08-29  20:45       Serie A     Matchweek 2  Sun  Home        W   4
# 2   2021-09-12  18:00       Serie A     Matchweek 3  Sun  Home        W   2
# 3   2021-09-15  20:00  Champions Lg     Group stage  Wed  Away        L   2
# 4   2021-09-19  20:45       Serie A     Matchweek 4  Sun  Away        D   1
# 5   2021-09-22  20:45       Serie A     Matchweek 5  Wed  Home        W   2
# 6   2021-09-25  15:00       Serie A     Matchweek 6  Sat  Away        W   2
# 7   2021-09-28  21:00  Champions Lg     Group stage  Tue  Home        L   1
# 8   2021-10-03  20:45       Serie A     Matchweek 7  Sun  Away        W   3
# 9   2021-10-16  20:45       Serie A     Matchweek 8  Sat  Home        W   3
# ...

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data
# Out:
#           Date   Time          Comp           Round  Day Venue Result  GF  GA  \
# 0   2021-08-23  20:45       Serie A     Matchweek 1  Mon  Away      W   1   0
# 1   2021-08-29  20:45       Serie A     Matchweek 2  Sun  Home      W   4   1
# 2   2021-09-12  18:00       Serie A     Matchweek 3  Sun  Home      W   2   0
# 3   2021-09-15  20:00  Champions Lg     Group stage  Wed  Away      L   2   3
# 4   2021-09-19  20:45       Serie A     Matchweek 4  Sun  Away      D   1   1
# 5   2021-09-22  20:45       Serie A     Matchweek 5  Wed  Home      W   2   0
# 6   2021-09-25  15:00       Serie A     Matchweek 6  Sat  Away      W   2   1
# 7   2021-09-28  21:00  Champions Lg     Group stage  Tue  Home      L   1   2
# 8   2021-10-03  20:45       Serie A     Matchweek 7  Sun  Away      W   3   2
# 9   2021-10-16  20:45       Serie A     Matchweek 8  Sat  Home      W   3   2
# 10  2021-10-19  20:00  Champions Lg     Group stage  Tue  Away      L   0   1
# ...

# %%
team_data.to_csv("matches_11_12.csv")

# %%
df = pd.read_csv('matches_11_12.csv')
df
# Out:
#     Unnamed: 0        Date   Time          Comp           Round  Day Venue  \
# 0            0  2021-08-23  20:45       Serie A     Matchweek 1  Mon  Away
# 1            1  2021-08-29  20:45       Serie A     Matchweek 2  Sun  Home
# 2            2  2021-09-12  18:00       Serie A     Matchweek 3  Sun  Home
# 3            3  2021-09-15  20:00  Champions Lg     Group stage  Wed  Away
# 4            4  2021-09-19  20:45       Serie A     Matchweek 4  Sun  Away
# 5            5  2021-09-22  20:45       Serie A     Matchweek 5  Wed  Home
# 6            6  2021-09-25  15:00       Serie A     Matchweek 6  Sat  Away
# 7            7  2021-09-28  21:00  Champions Lg     Group stage  Tue  Home
# 8            8  2021-10-03  20:45       Serie A     Matchweek 7  Sun  Away
# 9            9  2021-10-16  20:45       Serie A     Matchweek 8  Sat  Home
# 10          10  2021-10-19  20:00  Champions Lg     Group stage  Tue  Away
# ...

# %%
standings_url = 'https://fbref.com/en/comps/11/2020-2021/2020-2021-Serie-A-Stats'
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]
data = requests.get(team_urls[0])
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.columns = shooting.columns.droplevel()
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.to_csv("matches_10_11.csv")

# %%
standings_url = 'https://fbref.com/en/comps/11/2019-2020/2019-2020-Serie-A-Stats'
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]
data = requests.get(team_urls[0])
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.columns = shooting.columns.droplevel()
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.to_csv("matches_19_20.csv")

# %%
standings_url = 'https://fbref.com/en/comps/11/2018-2019/2018-2019-Serie-A-Stats'
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]
data = requests.get(team_urls[0])
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.columns = shooting.columns.droplevel()
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.to_csv("matches_18_19.csv")

# %%
standings_url = 'https://fbref.com/en/comps/11/2017-2018/2017-2018-Serie-A-Stats'
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]
data = requests.get(team_urls[0])
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.columns = shooting.columns.droplevel()
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.to_csv("matches_17_18.csv")

# %%
matches_21_22 = pd.read_csv('matches_21_22.csv')
matches_20_21 = pd.read_csv('matches_20_21.csv')
matches_19_20 = pd.read_csv('matches_19_20.csv')
matches_18_19 = pd.read_csv('matches_18_19.csv')
matches_17_18 = pd.read_csv('matches_17_18.csv')

# %%
matches = pd.concat([matches_21_22, matches_20_21, matches_19_20, matches_18_19, matches_17_18], ignore_index=True)

# %%
matches
# Out:
#      Unnamed: 0        Date   Time          Comp         Round  Day    Venue  \
# 0             0  2021-08-23  20:45       Serie A   Matchweek 1  Mon     Away
# 1             1  2021-08-29  20:45       Serie A   Matchweek 2  Sun     Home
# 2             2  2021-09-12  18:00       Serie A   Matchweek 3  Sun     Home
# 3             3  2021-09-15  20:00  Champions Lg   Group stage  Wed     Away
# 4             4  2021-09-19  20:45       Serie A   Matchweek 4  Sun     Away
# ..          ...         ...    ...           ...           ...  ...      ...
# 248          49  2018-04-28  20:45       Serie A  Matchweek 35  Sat     Away
# 249          50  2018-05-05  20:45       Serie A  Matchweek 36  Sat     Home
# 250          51  2018-05-09  21:00  Coppa Italia         Final  Wed  Neutral
# 251          52  2018-05-13  20:45       Serie A  Matchweek 37  Sun     Away
# 252          53  2018-05-19  15:00       Serie A  Matchweek 38  Sat     Home
#
# ...

# %%
matches.to_csv("matches.csv")
